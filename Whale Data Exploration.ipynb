# %%
import numpy as np
import pandas as pd
import pandas.rpy.common as com
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-965c83c1a808> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import pandas.rpy.common as com
#       4 import seaborn as sns
#       5 import statsmodels.api as sm
#
# /Users/isabel/anaconda/lib/python2.7/site-packages/pandas/rpy/common.py in <module>()
#      13 import pandas.util.testing as _test
#      14
# ---> 15 from rpy2.robjects.packages import importr
#      16 from rpy2.robjects import r
#      17 import rpy2.robjects as robj
#
# ImportError: No module named rpy2.robjects.packages

# %%
whales08 = pd.read_csv('whale data/seamap1065_names_2008.csv', index_col=0)

# %%
whales08
# Out:
#                 row_id  latitude  longitude sp_code  \
# dataset_id
# 1065        1065_18862     37.22    -126.68      MA
# 1065        1065_18863     37.22    -126.69      MA
# 1065        1065_18864     37.23    -126.74     177
# 1065        1065_18865     37.24    -126.79      CU
# 1065        1065_18866     37.28    -126.98      MA
# 1065        1065_18867     37.32    -127.17      MA
# 1065        1065_18868     37.38    -127.41      MA
# 1065        1065_18618     35.17    -125.83      70
# 1065        1065_18619     35.09    -125.67      49
# 1065        1065_18688     34.49    -125.70      CU
# 1065        1065_18689     34.51    -125.70      CU
# 1065        1065_18690     34.53    -125.69      CU
# 1065        1065_18691     34.55    -125.69      UA
# 1065        1065_18692     34.55    -125.69      CU
# 1065        1065_18693     34.58    -125.68      CU
# 1065        1065_18694     34.59    -125.67      CU
# 1065        1065_18695     34.63    -125.66      CU
# ...
